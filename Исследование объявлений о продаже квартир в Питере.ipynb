# %% [markdown]
# # Исследование объявлений о продаже квартир в Санкт-Петербурге
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Описание данных
#
# `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м),
# `balcony` — число балконов,
# `ceiling_height` — высота потолков (м),
# `cityCenters_nearest` — расстояние до центра города (м),
# `days_exposition` — сколько дней было размещено объявление (от публикации до снятия),
# `first_day_exposition` — дата публикации,
# `floor` — этаж,
# `floors_tota` — всего этажей в доме,
# `is_apartment` — апартаменты (булев тип),
# `kitchen_area` — площадь кухни в квадратных метрах (м²),
# `last_price` — цена на момент снятия с публикации,
# `living_area` — жилая площадь в квадратных метрах (м²),
# `locality_name` — название населённого пункта,
# `open_plan` — свободная планировка (булев тип),
# `parks_around3000` — число парков в радиусе 3 км,
# `parks_nearest` — расстояние до ближайшего парка (м),
# `ponds_around3000` — число водоёмов в радиусе 3 км,
# `ponds_nearest` — расстояние до ближайшего водоёма (м),
# `rooms` — число комнат,
# `studio` — квартира-студия (булев тип),
# `total_area` — общая площадь квартиры в квадратных метрах (м²),
# `total_images` — число фотографий квартиры в объявлении.

# %% [markdown]
# ## План выполнения проекта
#
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
# 1. Загрузите данные из csv-файла в датафрейм c помощью библиотеки pandas.
# 2. Изучите общую информацию о полученном датафрейме.
# 3. Постройте гистограмму для всех числовых столбцов таблицы на одном графике.
#
# **Шаг 2. Выполните предобработку данных**
# 1. Найдите и изучите пропущенные значения в столбцах:
#     - Определите, в каких столбцах есть пропуски.
#     - Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0. Если логичную замену предложить невозможно, то оставьте пропуски. Пропущенные значения — тоже важный сигнал, который нужно учитывать.
#     - В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# 2. Рассмотрите типы данных в каждом столбце:
# - Найдите столбцы, в которых нужно изменить тип данных.
# - Преобразуйте тип данных в выбранных столбцах.
# - В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# 3. Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
# **Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:**
# - цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).
#
# **Шаг 4. Проведите исследовательский анализ данных:**
# 1. Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров. В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
# _Список параметров:_
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка
# Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# 2. Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
# - Постройте гистограмму.
# - Посчитайте среднее и медиану.
# - В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# 3. Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
# Изучите, зависит ли цена от:
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# 4. Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# 5. Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.
#
# **Шаг 5. Напишите общий вывод**
# Опишите полученные результаты и зафиксируйте итоговый вывод проведённого исследования.

# %% [markdown]
# ### Загрузка и общая информация

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats

data = pd.read_csv('/datasets/real_estate_data.csv', sep="\t")
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Уже видно пропуски в 14 столбцах

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# А также по графику видно, что в некоторых столбцах выбросы

# %%
# зафиксируем изначальное количество данных для сравнения после обработки
original_shape = data.shape
print('Первоначальный размер данных :', original_shape)
# Out:
# Первоначальный размер данных : (23699, 22)

# %% [markdown]
# ### Предобработка данных

# %%
print('Пропуски и сколько')
data.isna().sum()
# Out:
# Пропуски и сколько
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# #### Столбец balcony

# %% [markdown]
# Заполним сначала самый очевидный столбец с балконами. Скорее всего, если не указали - их нет, т.е. 0

# %%
print('Значения этого столбца: ', *data['balcony'].unique())

data['balcony'] = data['balcony'].fillna(0)
# проверим, что все заполнилось
print('После замены количество NaN =', data['balcony'].isna().sum())
# Out:
# Значения этого столбца:  nan 2.0 0.0 1.0 5.0 4.0 3.0
# После замены количество NaN = 0

# %%
data['balcony'].plot.box()
plt.ylabel('Количество балконов')
plt.title('Разброс по балконам');

# %% [markdown]
#  3, 4, 5 балконов - это выбросы. Сколько всего таких значений?

# %%
data.loc[data['balcony'] >= 3, 'balcony'].count()
# Out:
# 568

# %%
# немного. удалим
data = data.loc[data['balcony'] < 3]

# %% [markdown]
# #### Столбец locality_name

# %%
# В locality_name сложно найти неявные дубликаты, и если есть NaN, то функция не будет работать.
# Сделаем NaN типа string - после устранения дубликотов вернем обратно
print('Пропуски до обработки:', data['locality_name'].isna().sum())
data['locality_name'] = data['locality_name'].fillna('None')
# Out:
# Пропуски до обработки: 48

# %%
np.sort(data['locality_name'].unique())
# Out:
# array(['None', 'Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск',
#        'Выборг', 'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород',
#        'Каменногорск', 'Кингисепп', 'Кириши', 'Кировск', 'Колпино',
#        'Коммунар', 'Красное Село', 'Кронштадт', 'Кудрово',
#        'Лодейное Поле', 'Ломоносов', 'Луга', 'Любань', 'Мурино',
#        'Никольское', 'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф',
#        'Пикалёво', 'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин',
#        'Санкт-Петербург', 'Светогорск', 'Сертолово', 'Сестрорецк',
#        'Сланцы', 'Сосновый Бор', 'Сясьстрой', 'Тихвин', 'Тосно',
#        'Шлиссельбург', 'городской поселок Большая Ижора',
#        'городской поселок Янино-1', 'городской посёлок Будогощь',
#        'городской посёлок Виллози', 'городской посёлок Лесогорский',
#        'городской посёлок Мга', 'городской посёлок Назия',
#        'городской посёлок Новоселье', 'городской посёлок Павлово',
# ...

# %%
data['locality_name'] = data['locality_name'].str.replace('ё','е')
to_replace = {
     r'(\b)поселок городского типа(\b)':r'\1городской поселок\2',
     r'(\b)поселок при железнодорожной станции(\b)':r'\1поселок станции\2',
     r'(\b)садоводческое некоммерческое товарищество(\b)':r'\1садовое товарищество\2'
}

data['locality_name'] = data['locality_name'].replace(to_replace, regex=True)

# %%
def categorize_locality_name(row):
    country_dict = {'Агалатово': 'деревня Агалатово',
'Александровская': 'поселок Александровская',
'Алексеевка': 'поселок Алексеевка',
'Аннино': 'поселок Аннино',
'Аро': 'деревня Аро',
'Барышево': 'поселок Барышево',
'Батово': 'деревня Батово',
'Бегуницы': 'деревня Бегуницы',
'Белогорка': 'деревня Белогорка',
'Белоостров': 'поселок Белоостров',
'Бокситогорск': 'Бокситогорск',
'Большая Вруда': 'деревня Большая Вруда',
'Большая Ижора': 'поселок городского типа Большая Ижора',
'Большая Пустомержа': 'деревня Большая Пустомержа',
'Большие Колпаны': 'деревня Большие Колпаны',
'Большое Рейзино': 'деревня Большое Рейзино',
'Большой Сабск': 'деревня Большой Сабск',
'Бор': 'деревня Бор',
'Борисова Грива': 'деревня Борисова Грива',
'Бугры': 'поселок Бугры',
'Будогощь': 'городской поселок Будогощь',
'Ваганово': 'деревня Ваганово',
'Старосиверская': 'деревня Старосиверская',
'Старые Бегуницы': 'деревня Старые Бегуницы',
'Стеклянный': 'поселок Стеклянный',
'Стрельна': 'поселок Стрельна',
'Суйда': 'поселок Суйда',
'Сумино': 'поселок Сумино',
'Суоранда': 'деревня Суоранда',
'Суходолье': 'поселок Суходолье',
'Счастье': 'коттеджный поселок Счастье',
'Сяськелево': 'деревня Сяськелево',
'Сясьстрой': 'Сясьстрой',
'Тайцы': 'поселок городского типа Тайцы',
'Тарасово': 'деревня Тарасово',
'Тельмана': 'поселок Тельмана',
'Терволово': 'поселок Терволово',
'Терпилицы': 'деревня Терпилицы',
'Тихвин': 'Тихвин',
'Тихковицы': 'деревня Тихковицы',
'Тойворово': 'деревня Тойворово',
'Токсово': 'поселок городского типа Токсово',
'Торковичи': 'поселок Торковичи',
'Торосово': 'деревня Торосово',
'Торошковичи': 'деревня Торошковичи',
'Торфяное': 'поселок Торфяное',
'Тосно': 'Тосно',
'Трубников Бор': 'деревня Трубников Бор',
'Тёсово-4': 'поселок Тёсово-4',
'Углово': 'поселок Углово',
'Ульяновка': 'поселок городского типа Ульяновка',
'Усть-Ижора': 'поселок Усть-Ижора',
'Усть-Луга': 'поселок Усть-Луга',
'Ушаки': 'поселок Ушаки',
'Фалилеево': 'деревня Фалилеево',
'Форносово': 'поселок городского типа Форносово',
'Форт Красная Горка': 'поселок Форт Красная Горка',
'деревня Фёдоровское': 'деревня Фёдоровское',
'Фёдоровское': 'городской поселок Фёдоровское',
'Хапо-Ое': 'деревня Хапо-Ое',
'Хязельки': 'деревня Хязельки',
'Цвелодубово': 'поселок Цвелодубово',
'Цвылёво': 'поселок Цвылёво',
'Чудской Бор': 'деревня Чудской Бор',
'Шлиссельбург': 'Шлиссельбург',
'Шпаньково': 'деревня Шпаньково',
'Шугозеро': 'поселок Шугозеро',
'Шум': 'село Шум',
'деревня Щеглово': 'деревня Щеглово',
'Шушары': 'поселок Шушары',
'Щеглово': 'поселок Щеглово',
'посёлок Щеглово': 'поселок Щеглово',
'Юкки': 'деревня Юкки',
'Ялгино': 'деревня Ялгино',
'Яльгелево': 'деревня Яльгелево',
'Ям-Тесово': 'деревня Ям-Тесово',
'Янино-1': 'городской поселок Янино-1'}   
    try:
        for key, value in country_dict.items():
            if key in row:
                return value
    except:
        return None

# %%
data['locality_name'] = data['locality_name'].apply(categorize_locality_name)
print(data['locality_name'].isna().sum())
#ind = data[data['total_locality_name'].isna()].index
#print(ind)
#(np.sort(data['total_locality_name'].unique()))
# Out:
# 110

# %% [markdown]
# Количество пропусков то же, что до обработки. Зато от неявных дубликатов избавились

# %% [markdown]
# #### Столбец ponds_nearest

# %%
data['ponds_nearest'].hist();

# %% [markdown]
# Выбросов не видно, все ближайшие водоемы находятся на расстоянии до 3000км. Надо только от пропусков избавиться

# %%
print('До замены, пропусков:', data['ponds_nearest'].isna().sum())
data.loc[(data['ponds_nearest'].isna()) & (data['ponds_around3000'] == 0 ), 'ponds_nearest'] = '-'
print('После:', data['ponds_nearest'].isna().sum())
# Out:
# До замены, пропусков: 14238
# После: 5398

# %% [markdown]
# **Обработка в parks_nearest**

# %%
data['parks_nearest'].hist();

# %% [markdown]
# То же самое с парками

# %%
print('До замены, пропусков:', data['parks_nearest'].isna().sum())
data.loc[(data['parks_nearest'].isna()) & (data['parks_around3000'] == 0 ), 'parks_nearest'] = '-'
print('После:', data['parks_nearest'].isna().sum())
# Out:
# До замены, пропусков: 15271
# После: 5398

# %% [markdown]
# #### Столбец ceiling_height

# %%
# теперь обработаем столбец с высотой потолков. Посмотрим уникальные значения
np.sort(data['ceiling_height'].unique())
# Out:
# array([ 1.  ,  1.2 ,  1.75,  2.  ,  2.2 ,  2.25,  2.3 ,  2.34,  2.4 ,
#         2.45,  2.46,  2.47,  2.48,  2.49,  2.5 ,  2.51,  2.52,  2.53,
#         2.54,  2.55,  2.56,  2.57,  2.58,  2.59,  2.6 ,  2.61,  2.62,
#         2.63,  2.64,  2.65,  2.66,  2.67,  2.68,  2.69,  2.7 ,  2.71,
#         2.72,  2.73,  2.74,  2.75,  2.76,  2.77,  2.78,  2.79,  2.8 ,
#         2.81,  2.82,  2.83,  2.84,  2.85,  2.86,  2.87,  2.88,  2.89,
#         2.9 ,  2.91,  2.92,  2.93,  2.94,  2.95,  2.96,  2.97,  2.98,
#         2.99,  3.  ,  3.01,  3.02,  3.03,  3.04,  3.05,  3.06,  3.07,
#         3.08,  3.09,  3.1 ,  3.11,  3.12,  3.13,  3.14,  3.15,  3.16,
#         3.17,  3.18,  3.2 ,  3.21,  3.22,  3.23,  3.24,  3.25,  3.26,
#         3.27,  3.28,  3.29,  3.3 ,  3.31,  3.32,  3.33,  3.34,  3.35,
#         3.36,  3.37,  3.38,  3.39,  3.4 ,  3.42,  3.43,  3.44,  3.45,
#         3.46,  3.47,  3.48,  3.49,  3.5 ,  3.51,  3.52,  3.53,  3.54,
# ...

# %%
# возможно, пользователи опечатались при вводе высоты потолков, которые оказались больше 10. Обработаем такие выбросы
data.loc[(data['ceiling_height'] > 10) & (data['ceiling_height'] < 100), 'ceiling_height'] = data['ceiling_height'] / 10

# %% [markdown]
# По нормам минимальная высота потолков: на кухне и в жилых комнатах - не менее 2,5-2,7 метра, в зависимости от климатического района. В коридоре, в прихожих, в холлах - 2,1 метра. В технических и подсобных помещениях высота потолка - 1,8 метра. В документации говорится о спб, т.е. будем считать что потолок должен быть не ниже 2.1м. Придется избавиться от строк, которые не вписываются в норму.
#
# Также есть и аномально высокие. Больше 5м тоже заполним NaN

# %%
# Мы собираемся избавиться от части данных. Оценим, насколько повлияет  наше действие на анализ датасета далее
data['ceiling_height'].hist(bins=100, range=(1, 20));

# %% [markdown]
# Видно, что если избавиться от квартир, высота потолков которых менее 2.1м и более 5м - это не сильно повлияет на дальнейший анализ.

# %%
data.loc[(data['ceiling_height'] < 2) | (data['ceiling_height'] > 5), 'ceiling_height'] = np.nan

# %%
# теперь обработаем столбец с высотой потолков. Заполним медианой пропуски, а таковых много
print('До категоризации:', data['ceiling_height'].isna().sum())
data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data.loc[:, 'ceiling_height'].median()

print('После заполнения части пропусков:', data['ceiling_height'].isna().sum())
# Out:
# До категоризации: 9089
# После заполнения части пропусков: 0

# %%
# посмтрим, что лишнее удалилось
np.sort(data['ceiling_height'].unique())
# Out:
# array([2.  , 2.2 , 2.25, 2.26, 2.3 , 2.34, 2.4 , 2.45, 2.46, 2.47, 2.48,
#        2.49, 2.5 , 2.51, 2.52, 2.53, 2.54, 2.55, 2.56, 2.57, 2.58, 2.59,
#        2.6 , 2.61, 2.62, 2.63, 2.64, 2.65, 2.66, 2.67, 2.68, 2.69, 2.7 ,
#        2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77, 2.78, 2.79, 2.8 , 2.81,
#        2.82, 2.83, 2.84, 2.85, 2.86, 2.87, 2.88, 2.89, 2.9 , 2.91, 2.92,
#        2.93, 2.94, 2.95, 2.96, 2.97, 2.98, 2.99, 3.  , 3.01, 3.02, 3.03,
#        3.04, 3.05, 3.06, 3.07, 3.08, 3.09, 3.1 , 3.11, 3.12, 3.13, 3.14,
#        3.15, 3.16, 3.17, 3.18, 3.2 , 3.21, 3.22, 3.23, 3.24, 3.25, 3.26,
#        3.27, 3.28, 3.29, 3.3 , 3.31, 3.32, 3.33, 3.34, 3.35, 3.36, 3.37,
#        3.38, 3.39, 3.4 , 3.42, 3.43, 3.44, 3.45, 3.46, 3.47, 3.48, 3.49,
#        3.5 , 3.51, 3.52, 3.53, 3.54, 3.55, 3.56, 3.57, 3.58, 3.59, 3.6 ,
#        3.62, 3.63, 3.65, 3.66, 3.67, 3.68, 3.69, 3.7 , 3.75, 3.76, 3.78,
#        3.8 , 3.82, 3.83, 3.84, 3.85, 3.86, 3.87, 3.88, 3.9 , 3.93, 3.95,
# ...

# %% [markdown]
# #### Столбец is_apartment

# %%
# скорее всего, елси не указали - то не апартаменты, так что заполним булевым значением
data.loc[data['is_apartment'].isna(), 'is_apartment'] = False

# %% [markdown]
# #### Краткий вывод

# %% [markdown]
#  Пропущенные значения были онаружены в столбцах ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition - всего 14 столбцов. Это довольно много.
#  Высота потолков имела выбросы. Они, а также пропуски, были заполнены медианой.
#  Большое число пропусков было обнаружено в is_apartment - является ли квартира апартаментами. Скорее сего пользователи не указывали, поэтому принято решение заполнить значением False(не апартаменты).
#  Аналогичная ситуация с балконами - если не указано, то считаем что его нет.
#  Таже было замечено, что пропущено значение в столбцах с расстоянием до ближайшего парка(parks_nearest) и водоема(ponds_nearest), если такового не находится в радиусе 3000м. Такие пропуски были заменены прочерком '-'.
#
#  Также в locality_name были обнаружены дубликаты как в виде "поселок" и посёлок", "городской поселок" и "поселок городского типа" (логическое несоответствие - первого понятия нет на картах) и т.п., так и территориальные дубликаты(когда, для пояснения, "Простоквашино" и "деревня Простоквашино" - одно и то же по Яндекс картам).
#
#  Очень много пропусков, предполагающих технические факторы, так как они находятся в столбцах, заполняемых компьютером. Большая их часть не нуждается в заполнении, так как данных достаточно для анализа.
#
# ** Рекомендуется** заменить настройки parks_nearest и ponds_nearest - при отсутствии парков в округе ставить значение, отличное от NaN(например, "-"). Сделать проверку высоты потолков - выводить предупреждение пользователю если больше 10 и меньше 1.8. Для апартаментов ввести галочку(тогда True или False подразумевается автоматически). Число балконов изначально ставить 0 и давать пользователю возможность переввести. А также проверить этапы загрузки, обработки и выгрузки данны в связи с бошльшим количеством пропусков в столбцах, заполняемых компьютером.

# %% [markdown]
# **Теперь заменим несколько типов данных**

# %%
# создадим список колонок, которым следует быть типа int
int_list = ['floors_total', 'rooms', 'balcony', 'total_images', 'floor', 'parks_around3000', 'ponds_around3000', 'days_exposition']
for column_name in int_list:
    data[column_name] = data[column_name].convert_dtypes('int')
    
# разделим дату и время публикации 
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S'
)  

float_list = ['last_price', 'total_area', 'ceiling_height', 'living_area', 'kitchen_area', 'airports_nearest', 'cityCenters_nearest', 'days_exposition']
for column_name in float_list:
    data[column_name] = data[column_name].astype('float32')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23131 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23131 non-null  Int64
#  1   last_price            23131 non-null  float32
#  2   total_area            23131 non-null  float32
#  3   first_day_exposition  23131 non-null  datetime64[ns]
#  4   rooms                 23131 non-null  Int64
#  5   ceiling_height        23131 non-null  float32
#  6   floors_total          23045 non-null  Int64
#  7   living_area           21262 non-null  float32
#  8   floor                 23131 non-null  Int64
#  9   is_apartment          23131 non-null  object
#  10  studio                23131 non-null  bool
#  11  open_plan             23131 non-null  bool
#  12  kitchen_area          20869 non-null  float32
#  13  balcony               23131 non-null  Int64
# ...

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0  108.000000           2019-03-07      3
# 1             7   3350000.0   40.400002           2018-12-04      1
# 2            10   5196000.0   56.000000           2015-08-20      2
# 3             0  64900000.0  159.000000           2015-07-24      3
# 4             2  10000000.0  100.000000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8        False  ...
# 1            2.65            11    18.600000      1        False  ...
# 2            2.65             5    34.299999      4        False  ...
# 3            2.65            14          NaN      9        False  ...
# 4            3.03            14    32.000000     13        False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23131 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23131 non-null  Int64
#  1   last_price            23131 non-null  float32
#  2   total_area            23131 non-null  float32
#  3   first_day_exposition  23131 non-null  datetime64[ns]
#  4   rooms                 23131 non-null  Int64
#  5   ceiling_height        23131 non-null  float32
#  6   floors_total          23045 non-null  Int64
#  7   living_area           21262 non-null  float32
#  8   floor                 23131 non-null  Int64
#  9   is_apartment          23131 non-null  object
#  10  studio                23131 non-null  bool
#  11  open_plan             23131 non-null  bool
#  12  kitchen_area          20869 non-null  float32
#  13  balcony               23131 non-null  Int64
# ...

# %% [markdown]
# Были изменены типы данных в столбцах floors_total, total_images, floor, balcony, parks_around3000, ponds_around3000, days_exposition поскольку эти значения по логике не должны быть дробными. Например, не может быть 1.5 картинки в объявлении.
# Также был изменен тип данных first_day_exposition(дата публикации) на datetime64, поскольку является датой и не имеет пропусков.

# %% [markdown]
# **Обработка выбросов**

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
data['total_images'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#есть выбросы. Посмотрим на значения и на гистрограмму
data['total_images'].unique()
# Out:
# <IntegerArray>
# [20,  7, 10,  0,  2,  6,  5, 18,  9,  1, 16, 11,  8, 12, 13,  3, 15, 17, 14,
#  19, 32,  4, 35, 39, 23, 21, 30, 24, 25, 28, 31, 22, 29, 26, 50, 42, 27, 37]
# Length: 38, dtype: Int64

# %%
data['total_images'].hist()
# Out:
# <AxesSubplot:>

# %%
#все значения больше 30 можно смело удалять
data = data.loc[data['total_images'] <= 30]

# %%
data['floor'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Можно ли жить на 18 этаже? - да. Оставим, это нельзя назвать выбросом

# %%
data['floors_total'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самое большое число этажей в здании Питера на момент 2023 года - 88. Возможно, это квартира в одном из небоскребов? Оставим.

# %%
data['kitchen_area'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Размер кухни в среднем может быть от 6 до 20 квадратных метров. Значение похоже на правду. Тож еоставим

# %%
data['last_price'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Кажется, цена около миллиарда. Кто-то выставил дворец? Это явно выбросы

# %%
data = data.loc[data['last_price'] < 20000000]

# %%
data['total_area'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data = data.loc[data['total_area'] < 110]

# %% [markdown]
# Аэропорт(столбец airports_nearest) может быть далеко, как и расстояние до центра города(cityCenters_nearest), до ближайшего парка(parks_nearest) и т.п. - все, что касается территориальных признаков. В них нет странностей вроде длины экватора - потому их не трогаем. Площадь квартиры(living_area) может быть 70 кв. м. - тоже оставим.

# %%
# предобработка завершена. Сбросим индексы
data.reset_index(drop= True)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0  108.000000           2019-03-07      3
# 1                 7   3350000.0   40.400002           2018-12-04      1
# 2                10   5196000.0   56.000000           2015-08-20      2
# 3                 2  10000000.0  100.000000           2018-06-19      2
# 4                10   2890000.0   30.400000           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 21660             9   4600000.0   62.400002           2016-08-05      3
# 21661            14   3100000.0   59.000000           2018-01-15      3
# 21662            18   2500000.0   56.700001           2018-02-11      2
# 21663            13  11475000.0   76.750000           2017-03-28      2
# 21664             4   1350000.0   32.299999           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
print('original_shape:', original_shape)
new_shape = data.shape
print('new_shape', data.shape)
print('Доля от изначального количества данных',new_shape[0]/original_shape[0])
# Out:
# original_shape: (23699, 22)
# new_shape (21665, 22)
# Доля от изначального количества данных 0.9141735938225242

# %% [markdown]
# ### Добавление новых столбцов

# %%
# создадим столбец "цена одного квадратного метра"
data['one_square_meter_price'] = round(data['last_price'] / data['total_area'], 2)

# %%
# различные даты
data['day'] = pd.DatetimeIndex(data['first_day_exposition']).weekday 
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month 
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %%
def floor_type(raw):
    try:
        if raw['floor'] == 1:
            return 'первый'
        elif raw['floor'] == raw['floors_total']:
            return 'последний'
        else:
            return 'другой'
    except:
        return 'другой'

# %%
data['floor_type'] = data.apply(floor_type, axis = 1)

# %%
data['cityCenters_nearest_in_kilometers'] = data['cityCenters_nearest'] // 1000
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0  108.000000           2019-03-07      3
# 1             7   3350000.0   40.400002           2018-12-04      1
# 2            10   5196000.0   56.000000           2015-08-20      2
# 4             2  10000000.0  100.000000           2018-06-19      2
# 5            10   2890000.0   30.400000           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16    51.000000      8        False  ...
# 1            2.65            11    18.600000      1        False  ...
# 2            2.65             5    34.299999      4        False  ...
# 4            3.03            14    32.000000     13        False  ...
# 5            2.65            12    14.400000      5        False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# #### Краткий вывод

# %% [markdown]
# Добавлены новые столбцы:
# `one_square_meter_price` - цена одного квадратного метра,
# `day` - день недели публикации объявления,
# `month` - месяц публикации объявления,
# `year` - год публикации объявления,
# `floor_type` - тип этажа квартиры (значения — «первый», «последний», «другой»),
# `cityCenters_nearest_in_kilometers` - расстояние до центра города в километрах (в км)

# %% [markdown]
# ### Исследовательский анализ данных

# %%
data.describe()
# Out:
#        total_images  last_price    total_area         rooms  ceiling_height  \
# count  21665.000000     21665.0  21665.000000  21665.000000    21665.000000
# mean       9.714055   5070879.5     53.306648      1.919271        2.676981
# std        5.547996   2731682.5     18.407808      0.888384        0.187350
# min        0.000000     12190.0     12.000000      0.000000        2.000000
# 25%        6.000000   3300000.0     39.000000      1.000000        2.600000
# 50%        9.000000   4450000.0     49.599998      2.000000        2.650000
# 75%       14.000000   6100000.0     64.000000      3.000000        2.700000
# max       30.000000  19999000.0    109.699997      7.000000        5.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  21586.000000  19950.000000  21665.000000  19545.000000  21665.000000
# mean      10.767071     30.449213      5.886868      9.750265      0.510224
# ...

# %% [markdown]
# Общая площадь(total_area) в среднем составляет 56 квадратных метров. Причем первый квартиль - 39, а третий - 66. Зато максимальное - 109,7 кв.м. В датасете имеются семикомнатные квартиры, поэтому такое возможно.
# Жилая площадь(living_area) в среднем - около 30. Если смотреть на показатель общей площади, то на кухню, туалет, ванну и коридор остается примерно 19кв.м. По площади кухни(kitchen_area) примерно так и получается. Среднее - 9.7 кв.м. Пока все логично.
# Первый квартиль цены объекта(last_price) - 3.3млн, а среднее - 5.1млн. Получается, 0.09млн в среднем за квадратный метр. При этом количество комнат(rooms) обычно равно 2.
# Половина всего датасета имеет высоту потолков(ceiling_height) около 2.68м. Здесь мы почистили довольно большое количество данных.
# Общее количество этажей в доме(floors_total) обычно до 11, хотя более 75% данных имеют количество этажей больше 16. А даже есть многоэтажка - 60.
# Расстояние до центра города в метрах(cityCenters_nearest) даже для третьего квартиля составило до 16км - это все еще в Санкт-Питербурге, так что можно считать, что почти все квартиры нашего датасета находятся в городе, несмотря на разнообразие населенных пунктов в locality_name, часть которых находится далеко за границей города.

# %%
data.hist(figsize=(20, 20));

# %%
data['days_exposition'].hist(bins=100,range=(0, 100));

# %% [markdown]
# Так как датасет старый(выше видно, что есть 2014 год), то тогда действовали еще правила по автоматическому снятию объявления в 45,60,90 дней(до 4,5 млн — 45 дней, от 4,5 до 10 млн — 60 дней, от 10 млн — 90 дней) - это обясняет пики. Сейчас другие правила для Москвы, Санкт-Петербурга и их областей - объявление может висеть год.
# Заполним средним по сосденим значениям.

# %%
exposition_data = data[~data['days_exposition'].isin([45, 60, 90])]

# %%
exposition_data['days_exposition'].hist(bins=100,range=(0, 100));

# %% [markdown]
# Теперь, когда выбросы не влияют на среднюю - посмотрим как быстро продавались квартиры

# %%
exposition_data['days_exposition'].plot.box()
plt.ylabel('Количество дней')
plt.title('Дни размещения объявления');

# %%
print("Медиана времени продажи квартиры: {:.2f} дней".format(exposition_data['days_exposition'].median()))
print("Среднее время продажи квартиры: {:.2f} дней".format(exposition_data['days_exposition'].mean()))
# Out:
# Медиана времени продажи квартиры: 105.00 дней
# Среднее время продажи квартиры: 184.16 дней

# %%
print("Если меньше {:.2f} дней, то продажа слишком быстрая".format(exposition_data['days_exposition'].quantile(0.25)))
print("А если больше {:.2f} дней, то продавали долго".format(exposition_data['days_exposition'].quantile(0.75)))
# Out:
# Если меньше 40.00 дней, то продажа слишком быстрая
# А если больше 240.00 дней, то продавали долго

# %% [markdown]
# В данных имеются квартиры, которые висели больше года, потому среднее будет не так правдоподобно считать, как медиану. Т.о. продажи занимают 105 дня, или 3.5 месяца. Меньше 1.5 месяца - лишком быстро, больше 7 - слишком долго

# %% [markdown]
# #### Корр. цены и общей площади квартиры

# %%
correlation = data['last_price'].corr(data['total_area'])
(data.sort_values('total_area')
.plot(figsize=(12, 5), kind='scatter',x='total_area', y='last_price',
      alpha=0.1, title='Корр. цены и общей площади квартиры: {:.2f}'.format(correlation),
     ylabel = 'Цена', xlabel = 'Площадь квартиры'))
plt.show()

# %% [markdown]
# Как и следовало ожидать, чем больше площадь - тем выше цена, коэффициент корреляции Пирсона это подтверждает - 0,78

# %% [markdown]
# #### Корр. цены и жилой площади

# %%
correlation = data['last_price'].corr(data['living_area'])
(data.sort_values('living_area')
.plot( figsize=(12, 5), kind='scatter',x='living_area',y='last_price',
      alpha=0.1, title='Корр. цены и жилой площади: {:.2f}'.format(correlation),
     ylabel = 'Цена', xlabel = 'Площадь квартиры'))
plt.show()

# %% [markdown]
# Здесь динамика тоже прослеживается: Чем больше площадь, тем выще цена. Хотя коэффициент здесь явно меньше в сравнении с общей площаью квартир, а также имеется большое количество объявлений в диапазонах от 12 дод 24, от 26 до 35. Возможно, здесь какие-то стандартные размеры жилых комнат.

# %% [markdown]
# #### Корр. цены и площади кухни

# %%
correlation = data['last_price'].corr(data['kitchen_area'])
(data.sort_values('kitchen_area')
.plot( figsize=(12, 5), kind='scatter',x='kitchen_area',y='last_price',
      alpha=0.1, title='Корр. цены и площади кухни: {:.2f}'.format(correlation),
     ylabel = 'Цена', xlabel = 'Площадь '))
plt.show()

# %% [markdown]
# Тут тоже видно уплотнение. Большинство кухонь размером от 5 до 15 кв.м.  Обычно Кухня в современной квартире – это небольшое помещение площадью 6-9 кв.м., а те, что больше, скорее всего являются кухнями в квартире-студии, где она занимает место в углу или вдоль стены на общей площади 15 – 20 кв.м.

# %% [markdown]
# #### Зависимость средней цены от количества комнат

# %%
(data.
 pivot_table(index='rooms', values='last_price', aggfunc='median')
.plot(title='Зависимость средней цены от количества комнат', figsize=(10,5), kind='bar',
     ylabel = 'Цена', xlabel = 'Количество комнат', legend=False))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Чем больше комнат - тем больше общая площадь квартиры. Логично было ожидать, что с ростом количества комнат растет и цена

# %% [markdown]
# #### Зависимость средней цены от этажа

# %%
"""
теперь поищем закономерности между 
общей площади квартиры жилой площади;
площади кухни;
количества комнат;
этажа, на котором расположена квартира (первый, последний, другой);
даты размещения (день недели, месяц, год).
"""
(data.
 pivot_table(index='floor_type', values='last_price', aggfunc='median')
.plot(title='Зависимость средней цены от этажа', figsize=(10,5), kind='bar',
     ylabel = 'Цена', xlabel = 'Этаж', legend=False))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Видно, что зависимости, как таковой, нет. Ожидалось, что чем выше этаж - тем дороже квартира. Однако, выше всего медианная цена в категории "другой". Хотя можно заметиить, что цена на последнем этаже все же выше, чем на первом. Низкую цену на квартиры на первом и последнем этажах можно аргументировать плохими условиями - шум от улиц и моторов лифта, охлаждаемость помещения зимой

# %% [markdown]
# #### Зависимость средней цены от дня недели публикации

# %%
(data.
 pivot_table(index='day', values='last_price', aggfunc='median')
.plot(title='Зависимость средней цены от дня недели публикации', figsize=(10,5), kind='bar',
     ylabel = 'Цена', xlabel = 'День', legend=False))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Можно было бы подумать, что разная динамика у выходных и будней, но в целом, зависимости нет.

# %% [markdown]
# #### Зависимость средней цены от дня публикации

# %%
(data.
 pivot_table(index='month', values='last_price', aggfunc='median')
.plot(title='Зависимость средней цены от дня публикации', figsize=(10,5), kind='bar',
     ylabel = 'Цена', xlabel = 'Месяц', legend=False))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Также ничего нельзя сказать о месяце

# %% [markdown]
# #### Зависимость средней цены от дня публикации

# %%
(data.
 pivot_table(index='year', values='last_price', aggfunc='median')
.plot(title='Зависимость средней цены от дня публикации', figsize=(10,5), kind='bar',
     ylabel = 'Цена', xlabel = 'Год', legend=False))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# А вот год как-то сильно отличается. С 2014 по 2017 средняя цена падала по экспоненте. Но потом медленно снова начала расти

# %% [markdown]
# #### Cамое дорогое жилье

# %%
# сначала найдем где больше всего объявлений
dat = dict(data['locality_name'].value_counts().head(10))
# создадим новый датасет - проще будет обрабатывать
new_top10_data = data.loc[data['locality_name'].isin(dat)]
sorted_data = new_top10_data.pivot_table(index='locality_name',  values='one_square_meter_price', aggfunc='mean').sort_values('one_square_meter_price', ascending=False)
sorted_data.head(10)
# Out:
#                    one_square_meter_price
# locality_name
# Санкт-Петербург             108708.125000
# Пушкин                      101766.304688
# деревня Кудрово              95356.453125
# поселок Парголово            90417.203125
# поселок Мурино               86186.500000
# поселок Шушары               78914.609375
# Колпино                      75210.281250
# Гатчина                      68891.718750
# Всеволожск                   67204.523438
# Выборг                       58310.757812

# %% [markdown]
# Как и ожидалось, самое дорогое жилье в Санкт-Петербурге(109241). За ним идут Пушкин, деревня Кудрово,поселок Парголово, поселок Мурино. Самое дешевое - Всеволожск(67432), затем Гатчина, Колпино, поселок Шушары и Петергоф

# %%
# теперь отделим Питер от остальных городов
piter_data = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='cityCenters_nearest_in_kilometers', values='one_square_meter_price')
piter_data
# Out:
#                                    one_square_meter_price
# cityCenters_nearest_in_kilometers
# 0.0                                         130480.859375
# 1.0                                         134964.484375
# 2.0                                         121949.750000
# 3.0                                         119576.664062
# 4.0                                         129178.914062
# 5.0                                         127941.546875
# 6.0                                         126884.382812
# 7.0                                         123614.562500
# 8.0                                         115719.945312
# 9.0                                         108497.015625
# 10.0                                        109884.335938
# 11.0                                        105866.656250
# 12.0                                        107888.945312
# 13.0                                        106624.023438
# 14.0                                        104187.406250
# ...

# %% [markdown]
# #### Зависимость цены от удаленности от центра

# %%
(piter_data
.plot(title='Зависимость цены от удаленности от центра', figsize=(15,5), kind='bar',
     ylabel = 'Цена', xlabel = 'Километров от центра', legend=False))
plt.xticks(rotation=0)
plt.show();

# %% [markdown]
# В целом видно, что чем дальше от центра, тем меньше становится цена. Однако на расстоянии 27км значение резко возрасло. ВОзможно, там есть очень дорогие квартиры. Давайте посмотрим так ли это

# %%
data.query('cityCenters_nearest_in_kilometers == 27.0').sort_values('one_square_meter_price', ascending=False).head(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 748              13  14350000.0   74.000000           2017-11-28      2
# 12466            11  15000000.0   89.599998           2017-01-31      3
# 23316            16   6300000.0   39.400002           2016-05-16      1
# 15578            20  16000000.0  101.900002           2018-01-08      2
# 8997             11  13000000.0  100.000000           2019-03-28      3
# 556               0   3500000.0   28.500000           2018-06-06      1
# 6750              8   5800000.0   48.000000           2018-01-17      1
# 22619             8   6000000.0   50.000000           2018-09-25      3
# 12144            10   6300000.0   52.799999           2018-03-06      2
# 13375             3   3650000.0   31.000000           2016-07-01      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 748              3.13             5    30.000000      3        False  ...
# ...

# %% [markdown]
# Действительно, есть 3 объявления. Однако, у 2х из них площадь большая из-за 5ти комнат. А владелец однокомнатной с площадью 39,5 не может продать почти год. Как мы знаем, это довольно долго по сравнению с другими объявлениями. Поэтому в данных ошибок нет

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В данных были обнаружены пропуски в столбцах ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition - всего 14 столбцов. Это довольно много.
#  Пропуски в высоте потолков имели выбросы. Значения более 10м были устранены при предположении, что пользователь пропустил запятую. Пропуски, были заполнены медианой. Также для дальнейшего анализа были исключены данные с высотой ниже 2.1м и выше 5м.
#  Большое число пропусков было обнаружено в is_apartment - является ли квартира апартаментами. Скорее сего пользователи не указывали, поэтому принято решение заполнить значением False(не апартаменты).
#  Аналогичная ситуация с балконами - если не указано, то считали что его нет.
#  Таже было замечено, что пропущено значение в столбцах с расстоянием до ближайшего парка(parks_nearest) и водоема(ponds_nearest), если такового не находится в радиусе 3000м. Такие пропуски были заменены прочерком '-'.
#
#  В locality_name были обнаружены и устранены неявные дубликаты.
#
#  Были изменены типы данных в столбцах floors_total, total_images, floor, balcony, parks_around3000, ponds_around3000, days_exposition на целочисленные. last_price, total_area, ceiling_height, living_area, kitchen_area, airports_nearest, cityCenters_nearest, days_exposition на float32 для сохранения 449Кб памяти.
# Также был изменен тип данных first_day_exposition(дата публикации) на datetime64, поскольку является датой. Далее этот столбец разделили на несколько: день недели(day) с кодированием дней недели от 0 до 6, месяц(month) и год(year).
# Также добавились столбцы one_square_meter_price - цена за квадратный метр и перевод в километры расстояния от центра cityCenters_nearest_in_kilometers.
#
# Рассмотрели как быстро продавались квартиры. Было установлено, что нормальное время продажи составляет около 3,5 месяцев. Меньше 1.5 месяца - уже слишком быстро, больше 7 - долго. В данных имеются объявления, висящие больше года.
# Также была найдена положительная корреляция между ценой квартиры и ее общей площадью, жилой частью, кухней и количеством комнат: чем больше каждая из площадей, тем выше цена. Зависимости между этажом, на котором расположена квартира, не выявлено. Однако стоит заметить, что в целом, цена на последние этажи выше чем на первые. Дата размещения(день недели/месяц) на цену не влияет. Прослеживается динамика по годам, что связано больше с экономическими факторами, нежели данными, предоставленными в датасете.
#
# Далее были избраты 10 населенных пунктов с наибольшим числом объявлений. По этим данным выявлены с самой высокой стоимостью квадратного метра: Санкт-Питербург в среднем 108708, а с самой низкой: Выборг - 58310.
#
# Также посмотрели на зависимость цены на жилье от удаленности от центра с шагом в километр в Санкт-Питербурге. Как ожидалось, чем дальше от центра, тем меньше цена.
#
#  Рекомендации: Очень много пропусков, предполагающих технические факторы, так как они находятся в столбцах, заполняемых компьютером. Большая их часть не нуждается в заполнении, так как данных достаточно для анализа. Стоит заменить настройки parks_nearest и ponds_nearest - при отсутствии парков в округе ставить значение, отличное от NaN(например, "-"). Сделать проверку высоты потолков - выводить предупреждение пользователю если больше 10 и меньше 1.8. Для апартаментов ввести галочку(тогда True или False подразумевается автоматически). Число балконов изначально ставить 0 и давать пользователю возможность переввести. А также проверить этапы загрузки, обработки и выгрузки данны в связи с бошльшим количеством пропусков в столбцах, заполняемых компьютером.
